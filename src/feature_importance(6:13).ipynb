# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import GroupKFold
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.inspection import permutation_importance
# Out:
# /Users/krc/miniforge3/envs/krc2/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
train_t= pd.read_csv('/Users/krc/Documents/dev/Mini_project-modeling/data/train_transaction.csv')
train_i = pd.read_csv('/Users/krc/Documents/dev/Mini_project-modeling/data/train_identity.csv')

test_t= pd.read_csv('/Users/krc/Documents/dev/Mini_project-modeling/data/test_transaction.csv')
test_i = pd.read_csv('/Users/krc/Documents/dev/Mini_project-modeling/data/test_identity.csv')
submission = pd.read_csv('/Users/krc/Documents/dev/Mini_project-modeling/data/sample_submission.csv')

# %%
train_m = train_t.merge(train_i, how='left', on='TransactionID')
test_m = test_t.merge(test_i, how='left', on='TransactionID')

# %% [markdown]
# TransactionID 제외
#
# 1. 결측치 -999 fillna
# 2. object columns -> label encoding
# 3. feature importance check
# 4. 상위 column 구분
# 5. object columns -> one-hot encoding
# 6. feature importance check
# 7. 상위 column 구분
# 8. 모델생성 및 평가

# %%
from sklearn.preprocessing import LabelEncoder

# %%
X = train_m.drop(columns=['isFraud','TransactionID'])
y = train_m.isFraud

# %%
X[list(train_m.dtypes[train_m.dtypes.values=='object'].index)].fillna('nan', inplace=True)
# Out:
# /var/folders/80/27hpx_054dl1_m05qm2q2zqr0000gn/T/ipykernel_7234/1645329072.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[list(train_m.dtypes[train_m.dtypes.values=='object'].index)].fillna('nan', inplace=True)

# %%
X[list(train_m.dtypes[train_m.dtypes.values=='object'].index)] = X[list(train_m.dtypes[train_m.dtypes.values=='object'].index)].apply(LabelEncoder().fit_transform)

# %%
X.fillna(-999, inplace=True)

# %%
forest = RandomForestClassifier()
forest.fit(X,y)

importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

print('Feature ranking:')

for f in range(X.shape[1]):
    print('{}. feature {} ({:.3f})'.format(f + 1, X.columns[indices][f], importances[indices[f]]))

plt.figure(figsize=(15,15))
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
        color='r', yerr=std[indices], align='center')
plt.xticks(range(X.shape[1]), X.columns[indices], rotation=45)
plt.xlim([-1, X.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature TransactionDT (0.031)
# 2. feature TransactionAmt (0.027)
# 3. feature card1 (0.026)
# 4. feature card2 (0.024)
# 5. feature addr1 (0.020)
# 6. feature C1 (0.017)
# 7. feature C13 (0.016)
# 8. feature V258 (0.014)
# 9. feature C14 (0.013)
# 10. feature P_emaildomain (0.012)
# 11. feature card5 (0.012)
# 12. feature C11 (0.010)
# 13. feature D15 (0.010)
# 14. feature C12 (0.010)
# 15. feature C6 (0.009)
# 16. feature V45 (0.009)
# 17. feature C2 (0.009)
# 18. feature V257 (0.009)
# 19. feature dist1 (0.009)
# 20. feature D1 (0.008)
# 21. feature id_02 (0.008)
# 22. feature D2 (0.008)
# 23. feature V307 (0.008)
# 24. feature D4 (0.007)
# 25. feature D10 (0.007)
# 26. feature V310 (0.007)
# 27. feature V246 (0.006)
# 28. feature V200 (0.006)
# 29. feature V44 (0.006)
# 30. feature C7 (0.006)
# 31. feature id_31 (0.006)
# 32. feature V308 (0.006)
# 33. feature V189 (0.006)
# 34. feature id_20 (0.006)
# 35. feature V244 (0.006)
# 36. feature card4 (0.006)
# 37. feature V242 (0.006)
# 38. feature V317 (0.006)
# 39. feature card6 (0.006)
# 40. feature C8 (0.006)
# 41. feature C4 (0.005)
# 42. feature V188 (0.005)
# 43. feature V127 (0.005)
# 44. feature V283 (0.005)
# 45. feature V87 (0.005)
# 46. feature D11 (0.005)
# 47. feature C10 (0.005)
# 48. feature id_19 (0.005)
# 49. feature V312 (0.005)
# 50. feature V315 (0.005)
# 51. feature V314 (0.005)
# 52. feature C9 (0.005)
# 53. feature V313 (0.005)
# 54. feature V201 (0.005)
# 55. feature D5 (0.005)
# 56. feature DeviceInfo (0.005)
# 57. feature R_emaildomain (0.005)
# 58. feature V318 (0.005)
# 59. feature V199 (0.005)
# 60. feature D3 (0.005)
# 61. feature V306 (0.004)
# 62. feature V294 (0.004)
# 63. feature V130 (0.004)
# 64. feature V128 (0.004)
# 65. feature V187 (0.004)
# 66. feature M6 (0.004)
# 67. feature D8 (0.004)
# 68. feature V274 (0.004)
# 69. feature M4 (0.004)
# 70. feature id_05 (0.004)
# 71. feature id_01 (0.004)
# 72. feature V259 (0.004)
# 73. feature V243 (0.004)
# 74. feature V282 (0.004)
# 75. feature V245 (0.004)
# 76. feature V190 (0.004)
# 77. feature V133 (0.004)
# 78. feature V285 (0.004)
# 79. feature V62 (0.004)
# 80. feature V83 (0.003)
# 81. feature id_13 (0.003)
# 82. feature id_06 (0.003)
# 83. feature M5 (0.003)
# 84. feature V275 (0.003)
# 85. feature V131 (0.003)
# 86. feature V280 (0.003)
# 87. feature V96 (0.003)
# 88. feature M8 (0.003)
# 89. feature M9 (0.003)
# 90. feature V295 (0.003)
# 91. feature card3 (0.003)
# 92. feature V316 (0.003)
# 93. feature V273 (0.003)
# 94. feature V126 (0.003)
# 95. feature V291 (0.003)
# 96. feature D9 (0.003)
# 97. feature V231 (0.003)
# 98. feature V149 (0.003)
# 99. feature V86 (0.003)
# 100. feature V54 (0.003)
# 101. feature V76 (0.003)
# 102. feature V264 (0.003)
# 103. feature V38 (0.003)
# 104. feature V320 (0.003)
# 105. feature M3 (0.003)
# 106. feature V20 (0.003)
# 107. feature V232 (0.003)
# 108. feature V53 (0.003)
# 109. feature V204 (0.003)
# 110. feature V213 (0.003)
# 111. feature id_30 (0.003)
# 112. feature V61 (0.003)
# 113. feature dist2 (0.003)
# 114. feature V99 (0.003)
# 115. feature V134 (0.003)
# 116. feature V13 (0.003)
# 117. feature V102 (0.003)
# 118. feature V309 (0.002)
# 119. feature V78 (0.002)
# 120. feature M7 (0.002)
# 121. feature V82 (0.002)
# 122. feature V12 (0.002)
# 123. feature V186 (0.002)
# 124. feature V75 (0.002)
# 125. feature V219 (0.002)
# 126. feature id_33 (0.002)
# 127. feature C5 (0.002)
# 128. feature V281 (0.002)
# 129. feature V156 (0.002)
# 130. feature V218 (0.002)
# 131. feature V36 (0.002)
# 132. feature D14 (0.002)
# 133. feature M2 (0.002)
# 134. feature id_18 (0.002)
# 135. feature V19 (0.002)
# 136. feature V5 (0.002)
# 137. feature V296 (0.002)
# 138. feature V279 (0.002)
# 139. feature V178 (0.002)
# 140. feature V67 (0.002)
# 141. feature V287 (0.002)
# 142. feature V136 (0.002)
# 143. feature D12 (0.002)
# 144. feature D6 (0.002)
# 145. feature V289 (0.002)
# 146. feature V207 (0.002)
# 147. feature V97 (0.002)
# 148. feature V35 (0.002)
# 149. feature V132 (0.002)
# 150. feature V233 (0.002)
# 151. feature V56 (0.002)
# 152. feature V203 (0.002)
# 153. feature V212 (0.002)
# 154. feature V47 (0.002)
# 155. feature id_03 (0.002)
# 156. feature id_09 (0.002)
# 157. feature V52 (0.002)
# 158. feature V24 (0.002)
# 159. feature V37 (0.002)
# 160. feature V292 (0.002)
# 161. feature V77 (0.002)
# 162. feature ProductCD (0.002)
# 163. feature V321 (0.002)
# 164. feature V265 (0.002)
# 165. feature V179 (0.002)
# 166. feature V4 (0.002)
# 167. feature V103 (0.002)
# 168. feature V263 (0.002)
# 169. feature V155 (0.002)
# 170. feature V293 (0.002)
# 171. feature id_17 (0.002)
# 172. feature V222 (0.002)
# 173. feature V209 (0.002)
# 174. feature V194 (0.002)
# 175. feature V74 (0.002)
# 176. feature V298 (0.002)
# 177. feature DeviceType (0.001)
# 178. feature V148 (0.001)
# 179. feature V23 (0.001)
# 180. feature V129 (0.001)
# 181. feature id_14 (0.001)
# 182. feature V124 (0.001)
# 183. feature D13 (0.001)
# 184. feature V288 (0.001)
# 185. feature V34 (0.001)
# 186. feature V3 (0.001)
# 187. feature V268 (0.001)
# 188. feature V66 (0.001)
# 189. feature V261 (0.001)
# 190. feature V223 (0.001)
# 191. feature V198 (0.001)
# 192. feature V137 (0.001)
# 193. feature V51 (0.001)
# 194. feature V100 (0.001)
# 195. feature V208 (0.001)
# 196. feature V40 (0.001)
# 197. feature id_38 (0.001)
# 198. feature V7 (0.001)
# 199. feature V55 (0.001)
# 200. feature V168 (0.001)
# 201. feature V39 (0.001)
# 202. feature V247 (0.001)
# 203. feature V224 (0.001)
# 204. feature V267 (0.001)
# 205. feature V26 (0.001)
# 206. feature V202 (0.001)
# 207. feature V262 (0.001)
# 208. feature V277 (0.001)
# 209. feature V95 (0.001)
# 210. feature V94 (0.001)
# 211. feature V9 (0.001)
# 212. feature V46 (0.001)
# 213. feature V153 (0.001)
# 214. feature V221 (0.001)
# 215. feature V171 (0.001)
# 216. feature V197 (0.001)
# 217. feature V154 (0.001)
# 218. feature V210 (0.001)
# 219. feature V43 (0.001)
# 220. feature V266 (0.001)
# 221. feature V228 (0.001)
# 222. feature V177 (0.001)
# 223. feature V2 (0.001)
# 224. feature V311 (0.001)
# 225. feature V195 (0.001)
# 226. feature V69 (0.001)
# 227. feature V256 (0.001)
# 228. feature V105 (0.001)
# 229. feature addr2 (0.001)
# 230. feature D7 (0.001)
# 231. feature V6 (0.001)
# 232. feature V11 (0.001)
# 233. feature V250 (0.001)
# 234. feature V49 (0.001)
# 235. feature V319 (0.001)
# 236. feature V301 (0.001)
# 237. feature V290 (0.001)
# 238. feature V10 (0.001)
# 239. feature V135 (0.001)
# 240. feature V332 (0.001)
# 241. feature id_15 (0.001)
# 242. feature V91 (0.001)
# 243. feature V251 (0.001)
# 244. feature id_16 (0.001)
# 245. feature V25 (0.001)
# 246. feature V42 (0.001)
# 247. feature V278 (0.001)
# 248. feature V167 (0.001)
# 249. feature V211 (0.001)
# 250. feature V271 (0.001)
# 251. feature V73 (0.001)
# 252. feature V215 (0.001)
# 253. feature V170 (0.001)
# 254. feature V8 (0.001)
# 255. feature V249 (0.001)
# 256. feature V255 (0.001)
# 257. feature V272 (0.001)
# 258. feature V125 (0.001)
# 259. feature V333 (0.001)
# 260. feature V323 (0.001)
# 261. feature V229 (0.001)
# 262. feature V299 (0.001)
# 263. feature V284 (0.001)
# 264. feature V101 (0.001)
# 265. feature V48 (0.001)
# 266. feature V81 (0.001)
# 267. feature V70 (0.001)
# 268. feature V270 (0.001)
# 269. feature id_37 (0.001)
# 270. feature V30 (0.001)
# 271. feature V90 (0.001)
# 272. feature V234 (0.001)
# 273. feature V217 (0.001)
# 274. feature V324 (0.001)
# 275. feature V29 (0.001)
# 276. feature V276 (0.001)
# 277. feature V85 (0.001)
# 278. feature V33 (0.001)
# 279. feature V172 (0.001)
# 280. feature V158 (0.001)
# 281. feature V225 (0.001)
# 282. feature V193 (0.001)
# 283. feature id_35 (0.001)
# 284. feature V216 (0.001)
# 285. feature V300 (0.001)
# 286. feature V16 (0.001)
# 287. feature V169 (0.001)
# 288. feature V79 (0.001)
# 289. feature V98 (0.001)
# 290. feature V115 (0.001)
# 291. feature V205 (0.001)
# 292. feature id_32 (0.001)
# 293. feature V152 (0.001)
# 294. feature V59 (0.001)
# 295. feature V58 (0.001)
# 296. feature V253 (0.001)
# 297. feature V248 (0.001)
# 298. feature V64 (0.001)
# 299. feature V175 (0.001)
# 300. feature V72 (0.001)
# 301. feature V252 (0.001)
# 302. feature id_11 (0.001)
# 303. feature V165 (0.001)
# 304. feature V150 (0.001)
# 305. feature V214 (0.001)
# 306. feature V106 (0.001)
# 307. feature id_10 (0.001)
# 308. feature id_28 (0.001)
# 309. feature V60 (0.001)
# 310. feature V123 (0.001)
# 311. feature V260 (0.001)
# 312. feature V322 (0.001)
# 313. feature id_04 (0.001)
# 314. feature id_34 (0.001)
# 315. feature V227 (0.001)
# 316. feature V139 (0.001)
# 317. feature V63 (0.001)
# 318. feature M1 (0.001)
# 319. feature V93 (0.001)
# 320. feature V166 (0.001)
# 321. feature V50 (0.001)
# 322. feature V140 (0.001)
# 323. feature V230 (0.001)
# 324. feature V80 (0.001)
# 325. feature V143 (0.001)
# 326. feature V286 (0.001)
# 327. feature V303 (0.001)
# 328. feature V236 (0.001)
# 329. feature V297 (0.001)
# 330. feature V157 (0.001)
# 331. feature V192 (0.001)
# 332. feature V1 (0.001)
# 333. feature V147 (0.001)
# 334. feature V331 (0.001)
# 335. feature V239 (0.001)
# 336. feature V196 (0.001)
# 337. feature V160 (0.001)
# 338. feature V57 (0.001)
# 339. feature V326 (0.001)
# 340. feature V164 (0.001)
# 341. feature id_29 (0.000)
# 342. feature V220 (0.000)
# 343. feature V84 (0.000)
# 344. feature V180 (0.000)
# 345. feature V145 (0.000)
# 346. feature id_12 (0.000)
# 347. feature V71 (0.000)
# 348. feature V206 (0.000)
# 349. feature V162 (0.000)
# 350. feature V41 (0.000)
# 351. feature V104 (0.000)
# 352. feature V176 (0.000)
# 353. feature V92 (0.000)
# 354. feature V112 (0.000)
# 355. feature V174 (0.000)
# 356. feature V109 (0.000)
# 357. feature V146 (0.000)
# 358. feature V116 (0.000)
# 359. feature V238 (0.000)
# 360. feature V15 (0.000)
# 361. feature V304 (0.000)
# 362. feature V184 (0.000)
# 363. feature id_36 (0.000)
# 364. feature V17 (0.000)
# 365. feature V185 (0.000)
# 366. feature id_21 (0.000)
# 367. feature V302 (0.000)
# 368. feature id_26 (0.000)
# 369. feature V182 (0.000)
# 370. feature V18 (0.000)
# 371. feature V237 (0.000)
# 372. feature V335 (0.000)
# 373. feature id_08 (0.000)
# 374. feature V338 (0.000)
# 375. feature id_07 (0.000)
# 376. feature V151 (0.000)
# 377. feature V163 (0.000)
# 378. feature V254 (0.000)
# 379. feature V235 (0.000)
# 380. feature V22 (0.000)
# 381. feature id_25 (0.000)
# 382. feature V161 (0.000)
# 383. feature V31 (0.000)
# 384. feature V159 (0.000)
# 385. feature V183 (0.000)
# 386. feature V226 (0.000)
# 387. feature V173 (0.000)
# 388. feature V114 (0.000)
# 389. feature V141 (0.000)
# 390. feature id_23 (0.000)
# 391. feature V32 (0.000)
# 392. feature V144 (0.000)
# 393. feature V336 (0.000)
# 394. feature V21 (0.000)
# 395. feature V181 (0.000)
# 396. feature V110 (0.000)
# 397. feature V65 (0.000)
# 398. feature V269 (0.000)
# 399. feature id_24 (0.000)
# 400. feature V108 (0.000)
# 401. feature V88 (0.000)
# 402. feature V89 (0.000)
# 403. feature V339 (0.000)
# 404. feature V113 (0.000)
# 405. feature V327 (0.000)
# 406. feature V334 (0.000)
# 407. feature V329 (0.000)
# 408. feature V68 (0.000)
# 409. feature V191 (0.000)
# 410. feature V337 (0.000)
# 411. feature V111 (0.000)
# 412. feature id_22 (0.000)
# 413. feature V330 (0.000)
# 414. feature V138 (0.000)
# 415. feature V142 (0.000)
# 416. feature V28 (0.000)
# 417. feature V27 (0.000)
# 418. feature V121 (0.000)
# 419. feature V328 (0.000)
# 420. feature id_27 (0.000)
# 421. feature V14 (0.000)
# 422. feature V325 (0.000)
# 423. feature V240 (0.000)
# 424. feature V122 (0.000)
# 425. feature V241 (0.000)
# 426. feature V117 (0.000)
# 427. feature V119 (0.000)
# 428. feature V118 (0.000)
# 429. feature V120 (0.000)
# 430. feature C3 (0.000)
# 431. feature V107 (0.000)
# 432. feature V305 (0.000)

# %%
forest = RandomForestClassifier()
forest.fit(X,y)

importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

print('Feature ranking:')

for f in range(X.shape[1]):
    print('{}. feature {} ({:.3f})'.format(f + 1, X.columns[indices][f], importances[indices[f]]))

plt.figure(figsize=(15,15))
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
        color='r', yerr=std[indices], align='center')
plt.xticks(range(X.shape[1]), X.columns[indices], rotation=45)
plt.xlim([-1, X.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature TransactionDT (0.031)
# 2. feature TransactionAmt (0.027)
# 3. feature card1 (0.026)
# 4. feature card2 (0.023)
# 5. feature addr1 (0.020)
# 6. feature C1 (0.017)
# 7. feature C13 (0.017)
# 8. feature C14 (0.012)
# 9. feature P_emaildomain (0.012)
# 10. feature card5 (0.012)
# 11. feature V244 (0.011)
# 12. feature V258 (0.011)
# 13. feature V45 (0.010)
# 14. feature D15 (0.010)
# 15. feature C2 (0.010)
# 16. feature C11 (0.009)
# 17. feature C6 (0.009)
# 18. feature dist1 (0.009)
# 19. feature D2 (0.009)
# 20. feature D1 (0.009)
# 21. feature C12 (0.008)
# 22. feature id_02 (0.008)
# 23. feature V307 (0.008)
# 24. feature D10 (0.007)
# 25. feature D4 (0.007)
# 26. feature V242 (0.007)
# 27. feature V257 (0.007)
# 28. feature V189 (0.007)
# 29. feature V201 (0.007)
# 30. feature V310 (0.007)
# 31. feature V308 (0.006)
# 32. feature V188 (0.006)
# 33. feature C4 (0.006)
# 34. feature V200 (0.006)
# 35. feature id_31 (0.006)
# 36. feature id_20 (0.006)
# 37. feature C8 (0.006)
# 38. feature card4 (0.006)
# 39. feature V44 (0.006)
# 40. feature V246 (0.006)
# 41. feature C7 (0.006)
# 42. feature V317 (0.006)
# 43. feature card6 (0.006)
# 44. feature V127 (0.005)
# 45. feature C10 (0.005)
# 46. feature D11 (0.005)
# 47. feature V187 (0.005)
# 48. feature id_19 (0.005)
# 49. feature V315 (0.005)
# 50. feature V283 (0.005)
# 51. feature V313 (0.005)
# 52. feature C9 (0.005)
# 53. feature V318 (0.005)
# 54. feature DeviceInfo (0.005)
# 55. feature D5 (0.005)
# 56. feature V314 (0.005)
# 57. feature V86 (0.005)
# 58. feature V306 (0.005)
# 59. feature V87 (0.005)
# 60. feature V274 (0.005)
# 61. feature R_emaildomain (0.005)
# 62. feature V312 (0.005)
# 63. feature V243 (0.005)
# 64. feature V130 (0.005)
# 65. feature V190 (0.004)
# 66. feature D3 (0.004)
# 67. feature V128 (0.004)
# 68. feature V294 (0.004)
# 69. feature M6 (0.004)
# 70. feature D8 (0.004)
# 71. feature M4 (0.004)
# 72. feature V245 (0.004)
# 73. feature id_01 (0.004)
# 74. feature id_05 (0.004)
# 75. feature V133 (0.004)
# 76. feature V282 (0.004)
# 77. feature V62 (0.004)
# 78. feature V285 (0.004)
# 79. feature V156 (0.004)
# 80. feature id_13 (0.003)
# 81. feature M5 (0.003)
# 82. feature id_06 (0.003)
# 83. feature V259 (0.003)
# 84. feature V83 (0.003)
# 85. feature V131 (0.003)
# 86. feature V96 (0.003)
# 87. feature M9 (0.003)
# 88. feature V213 (0.003)
# 89. feature card3 (0.003)
# 90. feature V273 (0.003)
# 91. feature V126 (0.003)
# 92. feature V280 (0.003)
# 93. feature V199 (0.003)
# 94. feature M8 (0.003)
# 95. feature V295 (0.003)
# 96. feature V291 (0.003)
# 97. feature D9 (0.003)
# 98. feature V76 (0.003)
# 99. feature V134 (0.003)
# 100. feature V20 (0.003)
# 101. feature V38 (0.003)
# 102. feature V54 (0.003)
# 103. feature V320 (0.003)
# 104. feature V232 (0.003)
# 105. feature M3 (0.003)
# 106. feature V13 (0.003)
# 107. feature V316 (0.003)
# 108. feature V102 (0.003)
# 109. feature V12 (0.003)
# 110. feature V82 (0.003)
# 111. feature dist2 (0.003)
# 112. feature V212 (0.003)
# 113. feature id_30 (0.003)
# 114. feature V99 (0.003)
# 115. feature V53 (0.002)
# 116. feature V61 (0.002)
# 117. feature M7 (0.002)
# 118. feature V309 (0.002)
# 119. feature id_33 (0.002)
# 120. feature V78 (0.002)
# 121. feature V75 (0.002)
# 122. feature C5 (0.002)
# 123. feature D14 (0.002)
# 124. feature M2 (0.002)
# 125. feature V275 (0.002)
# 126. feature V36 (0.002)
# 127. feature V279 (0.002)
# 128. feature V281 (0.002)
# 129. feature V19 (0.002)
# 130. feature V67 (0.002)
# 131. feature V149 (0.002)
# 132. feature id_09 (0.002)
# 133. feature V186 (0.002)
# 134. feature V5 (0.002)
# 135. feature V194 (0.002)
# 136. feature id_18 (0.002)
# 137. feature V231 (0.002)
# 138. feature V97 (0.002)
# 139. feature V296 (0.002)
# 140. feature V132 (0.002)
# 141. feature V56 (0.002)
# 142. feature V230 (0.002)
# 143. feature V229 (0.002)
# 144. feature V289 (0.002)
# 145. feature V219 (0.002)
# 146. feature D12 (0.002)
# 147. feature D6 (0.002)
# 148. feature V287 (0.002)
# 149. feature V136 (0.002)
# 150. feature V35 (0.002)
# 151. feature V263 (0.002)
# 152. feature V264 (0.002)
# 153. feature ProductCD (0.002)
# 154. feature V24 (0.002)
# 155. feature V265 (0.002)
# 156. feature id_03 (0.002)
# 157. feature V203 (0.002)
# 158. feature V52 (0.002)
# 159. feature V37 (0.002)
# 160. feature V4 (0.002)
# 161. feature V77 (0.002)
# 162. feature V292 (0.002)
# 163. feature V321 (0.002)
# 164. feature V47 (0.002)
# 165. feature V298 (0.002)
# 166. feature V129 (0.002)
# 167. feature DeviceType (0.002)
# 168. feature id_14 (0.001)
# 169. feature V261 (0.001)
# 170. feature V170 (0.001)
# 171. feature V210 (0.001)
# 172. feature V209 (0.001)
# 173. feature V51 (0.001)
# 174. feature V3 (0.001)
# 175. feature V178 (0.001)
# 176. feature V23 (0.001)
# 177. feature V40 (0.001)
# 178. feature V74 (0.001)
# 179. feature V155 (0.001)
# 180. feature V251 (0.001)
# 181. feature id_17 (0.001)
# 182. feature V233 (0.001)
# 183. feature V217 (0.001)
# 184. feature V293 (0.001)
# 185. feature V103 (0.001)
# 186. feature V266 (0.001)
# 187. feature V211 (0.001)
# 188. feature V204 (0.001)
# 189. feature V288 (0.001)
# 190. feature V154 (0.001)
# 191. feature V223 (0.001)
# 192. feature id_38 (0.001)
# 193. feature V100 (0.001)
# 194. feature V137 (0.001)
# 195. feature V222 (0.001)
# 196. feature D13 (0.001)
# 197. feature V66 (0.001)
# 198. feature V153 (0.001)
# 199. feature V228 (0.001)
# 200. feature V7 (0.001)
# 201. feature V55 (0.001)
# 202. feature V207 (0.001)
# 203. feature V26 (0.001)
# 204. feature V208 (0.001)
# 205. feature V148 (0.001)
# 206. feature V262 (0.001)
# 207. feature V224 (0.001)
# 208. feature V95 (0.001)
# 209. feature V268 (0.001)
# 210. feature V168 (0.001)
# 211. feature V198 (0.001)
# 212. feature V171 (0.001)
# 213. feature V202 (0.001)
# 214. feature V256 (0.001)
# 215. feature V176 (0.001)
# 216. feature V34 (0.001)
# 217. feature addr2 (0.001)
# 218. feature V43 (0.001)
# 219. feature V277 (0.001)
# 220. feature V124 (0.001)
# 221. feature V267 (0.001)
# 222. feature V221 (0.001)
# 223. feature V46 (0.001)
# 224. feature D7 (0.001)
# 225. feature V218 (0.001)
# 226. feature V179 (0.001)
# 227. feature V9 (0.001)
# 228. feature V94 (0.001)
# 229. feature V11 (0.001)
# 230. feature V2 (0.001)
# 231. feature V319 (0.001)
# 232. feature V105 (0.001)
# 233. feature V6 (0.001)
# 234. feature V25 (0.001)
# 235. feature V70 (0.001)
# 236. feature V301 (0.001)
# 237. feature V49 (0.001)
# 238. feature V39 (0.001)
# 239. feature V125 (0.001)
# 240. feature id_15 (0.001)
# 241. feature V73 (0.001)
# 242. feature V215 (0.001)
# 243. feature V10 (0.001)
# 244. feature V290 (0.001)
# 245. feature V271 (0.001)
# 246. feature V158 (0.001)
# 247. feature V135 (0.001)
# 248. feature V48 (0.001)
# 249. feature V311 (0.001)
# 250. feature V205 (0.001)
# 251. feature V42 (0.001)
# 252. feature V30 (0.001)
# 253. feature V255 (0.001)
# 254. feature id_16 (0.001)
# 255. feature V333 (0.001)
# 256. feature V33 (0.001)
# 257. feature V101 (0.001)
# 258. feature V225 (0.001)
# 259. feature V91 (0.001)
# 260. feature V284 (0.001)
# 261. feature V69 (0.001)
# 262. feature V8 (0.001)
# 263. feature V299 (0.001)
# 264. feature id_37 (0.001)
# 265. feature V81 (0.001)
# 266. feature V272 (0.001)
# 267. feature V123 (0.001)
# 268. feature V234 (0.001)
# 269. feature V90 (0.001)
# 270. feature V332 (0.001)
# 271. feature V85 (0.001)
# 272. feature V278 (0.001)
# 273. feature V175 (0.001)
# 274. feature V216 (0.001)
# 275. feature V152 (0.001)
# 276. feature V247 (0.001)
# 277. feature V250 (0.001)
# 278. feature V323 (0.001)
# 279. feature V276 (0.001)
# 280. feature V72 (0.001)
# 281. feature V29 (0.001)
# 282. feature V79 (0.001)
# 283. feature V270 (0.001)
# 284. feature id_11 (0.001)
# 285. feature V300 (0.001)
# 286. feature V227 (0.001)
# 287. feature id_32 (0.001)
# 288. feature V195 (0.001)
# 289. feature V115 (0.001)
# 290. feature V50 (0.001)
# 291. feature id_34 (0.001)
# 292. feature V180 (0.001)
# 293. feature V253 (0.001)
# 294. feature V214 (0.001)
# 295. feature V58 (0.001)
# 296. feature V206 (0.001)
# 297. feature V98 (0.001)
# 298. feature V106 (0.001)
# 299. feature V93 (0.001)
# 300. feature id_04 (0.001)
# 301. feature id_10 (0.001)
# 302. feature V248 (0.001)
# 303. feature V60 (0.001)
# 304. feature V260 (0.001)
# 305. feature V220 (0.001)
# 306. feature V140 (0.001)
# 307. feature M1 (0.001)
# 308. feature V160 (0.001)
# 309. feature V63 (0.001)
# 310. feature V80 (0.001)
# 311. feature V254 (0.001)
# 312. feature V167 (0.001)
# 313. feature V331 (0.001)
# 314. feature V197 (0.001)
# 315. feature V64 (0.001)
# 316. feature V239 (0.001)
# 317. feature V303 (0.001)
# 318. feature V326 (0.001)
# 319. feature V139 (0.001)
# 320. feature V324 (0.001)
# 321. feature V59 (0.001)
# 322. feature V174 (0.001)
# 323. feature V18 (0.001)
# 324. feature V162 (0.001)
# 325. feature V172 (0.001)
# 326. feature id_28 (0.001)
# 327. feature V236 (0.001)
# 328. feature V92 (0.001)
# 329. feature V169 (0.001)
# 330. feature V286 (0.001)
# 331. feature V1 (0.001)
# 332. feature V143 (0.001)
# 333. feature V157 (0.001)
# 334. feature V57 (0.001)
# 335. feature V182 (0.001)
# 336. feature V147 (0.001)
# 337. feature V165 (0.001)
# 338. feature V304 (0.001)
# 339. feature V249 (0.001)
# 340. feature id_29 (0.000)
# 341. feature V84 (0.000)
# 342. feature V297 (0.000)
# 343. feature V177 (0.000)
# 344. feature V32 (0.000)
# 345. feature V16 (0.000)
# 346. feature id_35 (0.000)
# 347. feature V41 (0.000)
# 348. feature V335 (0.000)
# 349. feature V104 (0.000)
# 350. feature V238 (0.000)
# 351. feature V109 (0.000)
# 352. feature V164 (0.000)
# 353. feature V145 (0.000)
# 354. feature V150 (0.000)
# 355. feature V17 (0.000)
# 356. feature V15 (0.000)
# 357. feature V185 (0.000)
# 358. feature id_21 (0.000)
# 359. feature V166 (0.000)
# 360. feature V71 (0.000)
# 361. feature V338 (0.000)
# 362. feature V181 (0.000)
# 363. feature id_36 (0.000)
# 364. feature V184 (0.000)
# 365. feature V163 (0.000)
# 366. feature V116 (0.000)
# 367. feature V159 (0.000)
# 368. feature id_08 (0.000)
# 369. feature V21 (0.000)
# 370. feature id_26 (0.000)
# 371. feature V192 (0.000)
# 372. feature V183 (0.000)
# 373. feature V22 (0.000)
# 374. feature V173 (0.000)
# 375. feature V112 (0.000)
# 376. feature V237 (0.000)
# 377. feature V144 (0.000)
# 378. feature id_07 (0.000)
# 379. feature V191 (0.000)
# 380. feature V65 (0.000)
# 381. feature id_25 (0.000)
# 382. feature V336 (0.000)
# 383. feature V235 (0.000)
# 384. feature V151 (0.000)
# 385. feature V322 (0.000)
# 386. feature V146 (0.000)
# 387. feature V252 (0.000)
# 388. feature V329 (0.000)
# 389. feature V31 (0.000)
# 390. feature id_24 (0.000)
# 391. feature V226 (0.000)
# 392. feature V302 (0.000)
# 393. feature V161 (0.000)
# 394. feature V113 (0.000)
# 395. feature V108 (0.000)
# 396. feature V110 (0.000)
# 397. feature V142 (0.000)
# 398. feature V193 (0.000)
# 399. feature id_23 (0.000)
# 400. feature id_12 (0.000)
# 401. feature V68 (0.000)
# 402. feature V196 (0.000)
# 403. feature V114 (0.000)
# 404. feature V89 (0.000)
# 405. feature V339 (0.000)
# 406. feature V327 (0.000)
# 407. feature V88 (0.000)
# 408. feature V28 (0.000)
# 409. feature V241 (0.000)
# 410. feature id_22 (0.000)
# 411. feature V141 (0.000)
# 412. feature V337 (0.000)
# 413. feature V111 (0.000)
# 414. feature V328 (0.000)
# 415. feature V334 (0.000)
# 416. feature V27 (0.000)
# 417. feature V138 (0.000)
# 418. feature V330 (0.000)
# 419. feature V121 (0.000)
# 420. feature V269 (0.000)
# 421. feature id_27 (0.000)
# 422. feature V240 (0.000)
# 423. feature V14 (0.000)
# 424. feature V122 (0.000)
# 425. feature V325 (0.000)
# 426. feature V119 (0.000)
# 427. feature V118 (0.000)
# 428. feature V120 (0.000)
# 429. feature V117 (0.000)
# 430. feature C3 (0.000)
# 431. feature V107 (0.000)
# 432. feature V305 (0.000)

# %%
plt.figure(figsize=(15,15))
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
        color='r', yerr=std[indices], align='center')
plt.xticks(range(X.shape[1]), X.columns[indices], rotation=45)
plt.xlim([-1, 50])
plt.show()

# %%
forest = RandomForestClassifier()
forest.fit(X,y)

importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

print('Feature ranking:')

for f in range(X.shape[1]):
    print('{}. feature {} ({:.3f})'.format(f + 1, X.columns[indices][f], importances[indices[f]]))

plt.figure(figsize=(15,15))
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
        color='r', yerr=std[indices], align='center')
plt.xticks(range(X.shape[1]), X.columns[indices], rotation=45)
plt.xlim([-1, X.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature DeviceInfo (0.209)
# 2. feature id_31 (0.157)
# 3. feature P_emaildomain (0.128)
# 4. feature R_emaildomain (0.071)
# 5. feature id_30 (0.057)
# 6. feature id_33 (0.055)
# 7. feature card4 (0.050)
# 8. feature card6 (0.041)
# 9. feature M4 (0.031)
# 10. feature ProductCD (0.028)
# 11. feature id_38 (0.015)
# 12. feature id_29 (0.014)
# 13. feature id_12 (0.013)
# 14. feature DeviceType (0.012)
# 15. feature M5 (0.012)
# 16. feature id_16 (0.011)
# 17. feature M6 (0.011)
# 18. feature id_37 (0.011)
# 19. feature id_35 (0.011)
# 20. feature id_15 (0.010)
# 21. feature id_34 (0.009)
# 22. feature id_23 (0.007)
# 23. feature id_28 (0.007)
# 24. feature id_36 (0.006)
# 25. feature id_27 (0.004)
# 26. feature M8 (0.004)
# 27. feature M3 (0.004)
# 28. feature M7 (0.004)
# 29. feature M2 (0.003)
# 30. feature M9 (0.003)
# 31. feature M1 (0.001)

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=train_t,y='TransactionAmt', x='isFraud')
plt.ylim([-1, 400])
# Out:
# (-1.0, 400.0)

# %%
def find_feature_importance(X, model, show_plot): # RF로 중요한 feature 확인

    feat_names = X.columns.values
    importances = model.feature_importances_
    std = np.std([tree.feature_importances_ for tree in model.estimators_], axis=0)
    indices = np.argsort(importances)[::-1][:20]

    plt.figure(figsize=(12,12))
    plt.title("Feature importances")
    plt.bar(range(len(indices)), importances[indices], color="r", align="center")
    plt.xticks(range(len(indices)), feat_names[indices], rotation='vertical')
    plt.xlim([-1, len(indices)])
    plt.show()
    
    important_features = X.columns[importances >= 0.005]
    return important_features

# %%
train_m.id_31.isnull().sum()
# Out:
# 450258

# %%
train_m.isnull()
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt  ProductCD  \
# 0               False    False          False           False      False
# 1               False    False          False           False      False
# 2               False    False          False           False      False
# 3               False    False          False           False      False
# 4               False    False          False           False      False
# ...               ...      ...            ...             ...        ...
# 590535          False    False          False           False      False
# 590536          False    False          False           False      False
# 590537          False    False          False           False      False
# 590538          False    False          False           False      False
# 590539          False    False          False           False      False
#
#         card1  card2  card3  card4  card5  ...  id_31  id_32  id_33  id_34  \
# 0       False   True  False  False  False  ...   True   True   True   True
# 1       False  False  False  False  False  ...   True   True   True   True
# 2       False  False  False  False  False  ...   True   True   True   True
# 3       False  False  False  False  False  ...   True   True   True   True
# 4       False  False  False  False  False  ...  False  False  False  False
# ...       ...    ...    ...    ...    ...  ...    ...    ...    ...    ...
# 590535  False   True  False  False  False  ...   True   True   True   True
# 590536  False  False  False  False  False  ...   True   True   True   True
# 590537  False  False  False  False  False  ...   True   True   True   True
# 590538  False  False  False  False  False  ...   True   True   True   True
# 590539  False  False  False  False  False  ...   True   True   True   True
#
#         id_35  id_36  id_37  id_38  DeviceType  DeviceInfo
# 0        True   True   True   True        True        True
# 1        True   True   True   True        True        True
# 2        True   True   True   True        True        True
# 3        True   True   True   True        True        True
# 4       False  False  False  False       False       False
# ...       ...    ...    ...    ...         ...         ...
# 590535   True   True   True   True        True        True
# 590536   True   True   True   True        True        True
# 590537   True   True   True   True        True        True
# 590538   True   True   True   True        True        True
# 590539   True   True   True   True        True        True
#
# [590540 rows x 434 columns]
